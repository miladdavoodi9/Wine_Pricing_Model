# %%
import pandas as pd
import json

# %%
file1 = "Resources/winemag-data-130k-v2.csv"
file2 = "Resources/winemag-data_first150k.csv"
json_file = "Resources/winemag-data-130k-v2.json"

# %%
df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)
dfjson = pd.read_json(json_file)

# %%
df1.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
df1.drop(columns=["Unnamed: 0","taster_name", "taster_twitter_handle", "title"])
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# 1                                     Avidagos      87   15.0
# 2                                          NaN      87   14.0
# 3                         Reserve Late Harvest      87   13.0
# 4           Vintner's Reserve Wild Child Block      87   65.0
# ...                                        ...     ...    ...
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0
# 129967                                     NaN      90   75.0
# 129968                                   Kritt      90   30.0
# 129969                                     NaN      90   32.0
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0
#
#                  province             region_1           region_2  \
# 0       Sicily & Sardinia                 Etna                NaN
# 1                   Douro                  NaN                NaN
# 2                  Oregon    Willamette Valley  Willamette Valley
# 3                Michigan  Lake Michigan Shore                NaN
# 4                  Oregon    Willamette Valley  Willamette Valley
# ...                   ...                  ...                ...
# 129966              Mosel                  NaN                NaN
# 129967             Oregon               Oregon       Oregon Other
# 129968             Alsace               Alsace                NaN
# 129969             Alsace               Alsace                NaN
# 129970             Alsace               Alsace                NaN
#
#                variety                                    winery
# 0          White Blend                                   Nicosia
# 1       Portuguese Red                       Quinta dos Avidagos
# 2           Pinot Gris                                 Rainstorm
# 3             Riesling                                St. Julian
# 4           Pinot Noir                              Sweet Cheeks
# ...                ...                                       ...
# 129966        Riesling  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967      Pinot Noir                                  Citation
# 129968  Gewürztraminer                           Domaine Gresser
# 129969      Pinot Gris                      Domaine Marcel Deiss
# 129970  Gewürztraminer                          Domaine Schoffit
#
# [129971 rows x 10 columns]

# %%
df2.drop(columns=["Unnamed: 0"])
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# 1       Carodorum Selección Especial Reserva      96  110.0
# 2              Special Selected Late Harvest      96   90.0
# 3                                    Reserve      96   65.0
# 4                                 La Brûlade      95   66.0
# ...                                      ...     ...    ...
# 150925                                   NaN      91   20.0
# 150926                        Cuvée Prestige      91   27.0
# 150927                         Terre di Dora      91   20.0
# 150928                       Grand Brut Rosé      90   52.0
# 150929                                   NaN      90   15.0
#
#                   province           region_1           region_2  \
# 0               California        Napa Valley               Napa
# 1           Northern Spain               Toro                NaN
# 2               California     Knights Valley             Sonoma
# 3                   Oregon  Willamette Valley  Willamette Valley
# 4                 Provence             Bandol                NaN
# ...                    ...                ...                ...
# 150925      Southern Italy  Fiano di Avellino                NaN
# 150926           Champagne          Champagne                NaN
# 150927      Southern Italy  Fiano di Avellino                NaN
# 150928           Champagne          Champagne                NaN
# 150929  Northeastern Italy         Alto Adige                NaN
#
#                    variety                   winery
# 0       Cabernet Sauvignon                    Heitz
# 1            Tinta de Toro  Bodega Carmen Rodríguez
# 2          Sauvignon Blanc                 Macauley
# 3               Pinot Noir                    Ponzi
# 4       Provence red blend     Domaine de la Bégude
# ...                    ...                      ...
# 150925         White Blend    Feudi di San Gregorio
# 150926     Champagne Blend                H.Germain
# 150927         White Blend                Terredora
# 150928     Champagne Blend                   Gosset
# 150929        Pinot Grigio            Alois Lageder
#
# [150930 rows x 10 columns]

# %%
df3 = dfjson[["country", "description", "designation", "points", "price", "province", "region_1", "region_2", "variety", "winery"]]

# %%
df3.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                None      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         variety               winery
# 0                 Etna               None     White Blend              Nicosia
# 1                 None               None  Portuguese Red  Quinta dos Avidagos
# 2    Willamette Valley  Willamette Valley      Pinot Gris            Rainstorm
# 3  Lake Michigan Shore               None        Riesling           St. Julian
# 4    Willamette Valley  Willamette Valley      Pinot Noir         Sweet Cheeks

# %%
winedf = pd.concat([df1, df2, df3], axis=0)

# %%
winedf.drop(columns="Unnamed: 0")
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# 1                                     Avidagos      87   15.0
# 2                                          NaN      87   14.0
# 3                         Reserve Late Harvest      87   13.0
# 4           Vintner's Reserve Wild Child Block      87   65.0
# ...                                        ...     ...    ...
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0
# 129967                                    None      90   75.0
# 129968                                   Kritt      90   30.0
# 129969                                    None      90   32.0
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0
#
#                  province             region_1           region_2  \
# 0       Sicily & Sardinia                 Etna                NaN
# 1                   Douro                  NaN                NaN
# 2                  Oregon    Willamette Valley  Willamette Valley
# 3                Michigan  Lake Michigan Shore                NaN
# 4                  Oregon    Willamette Valley  Willamette Valley
# ...                   ...                  ...                ...
# 129966              Mosel                 None               None
# 129967             Oregon               Oregon       Oregon Other
# 129968             Alsace               Alsace               None
# 129969             Alsace               Alsace               None
# 129970             Alsace               Alsace               None
#
#                taster_name taster_twitter_handle  \
# 0            Kerin O’Keefe          @kerinokeefe
# 1               Roger Voss            @vossroger
# 2             Paul Gregutt           @paulgwine
# 3       Alexander Peartree                   NaN
# 4             Paul Gregutt           @paulgwine
# ...                    ...                   ...
# 129966                 NaN                   NaN
# 129967                 NaN                   NaN
# 129968                 NaN                   NaN
# 129969                 NaN                   NaN
# 129970                 NaN                   NaN
#
#                                                     title         variety  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
# ...                                                   ...             ...
# 129966                                                NaN        Riesling
# 129967                                                NaN      Pinot Noir
# 129968                                                NaN  Gewürztraminer
# 129969                                                NaN      Pinot Gris
# 129970                                                NaN  Gewürztraminer
#
#                                           winery
# 0                                        Nicosia
# 1                            Quinta dos Avidagos
# 2                                      Rainstorm
# 3                                     St. Julian
# 4                                   Sweet Cheeks
# ...                                          ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967                                  Citation
# 129968                           Domaine Gresser
# 129969                      Domaine Marcel Deiss
# 129970                          Domaine Schoffit
#
# [410872 rows x 13 columns]

# %%
winedf.dropna(subset=['points', 'price'])
# Out:
#         Unnamed: 0   country  \
# 1              1.0  Portugal
# 2              2.0        US
# 3              3.0        US
# 4              4.0        US
# 5              5.0     Spain
# ...            ...       ...
# 129966         NaN   Germany
# 129967         NaN        US
# 129968         NaN    France
# 129969         NaN    France
# 129970         NaN    France
#
#                                               description  \
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# 5       Blackberry and raspberry aromas show a typical...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# 129969  A dry style of Pinot Gris, this is crisp with ...
# 129970  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price        province  \
# 1                                     Avidagos      87   15.0           Douro
# 2                                          NaN      87   14.0          Oregon
# 3                         Reserve Late Harvest      87   13.0        Michigan
# 4           Vintner's Reserve Wild Child Block      87   65.0          Oregon
# 5                                 Ars In Vitro      87   15.0  Northern Spain
# ...                                        ...     ...    ...             ...
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0           Mosel
# 129967                                    None      90   75.0          Oregon
# 129968                                   Kritt      90   30.0          Alsace
# 129969                                    None      90   32.0          Alsace
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0          Alsace
#
#                    region_1           region_2         taster_name  \
# 1                       NaN                NaN          Roger Voss
# 2         Willamette Valley  Willamette Valley        Paul Gregutt
# 3       Lake Michigan Shore                NaN  Alexander Peartree
# 4         Willamette Valley  Willamette Valley        Paul Gregutt
# 5                   Navarra                NaN   Michael Schachner
# ...                     ...                ...                 ...
# 129966                 None               None                 NaN
# 129967               Oregon       Oregon Other                 NaN
# 129968               Alsace               None                 NaN
# 129969               Alsace               None                 NaN
# 129970               Alsace               None                 NaN
#
#        taster_twitter_handle  \
# 1                 @vossroger
# 2                @paulgwine
# 3                        NaN
# 4                @paulgwine
# 5                @wineschach
# ...                      ...
# 129966                   NaN
# 129967                   NaN
# 129968                   NaN
# 129969                   NaN
# 129970                   NaN
#
#                                                     title             variety  \
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)      Portuguese Red
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)          Pinot Gris
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 5       Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# ...                                                   ...                 ...
# 129966                                                NaN            Riesling
# 129967                                                NaN          Pinot Noir
# 129968                                                NaN      Gewürztraminer
# 129969                                                NaN          Pinot Gris
# 129970                                                NaN      Gewürztraminer
#
#                                           winery
# 1                            Quinta dos Avidagos
# 2                                      Rainstorm
# 3                                     St. Julian
# 4                                   Sweet Cheeks
# 5                                         Tandem
# ...                                          ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967                                  Citation
# 129968                           Domaine Gresser
# 129969                      Domaine Marcel Deiss
# 129970                          Domaine Schoffit
#
# [379185 rows x 14 columns]

# %%
finalwinedf = winedf.drop(columns="Unnamed: 0")

# %%
finalwinedf.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
finalwinedf.to_csv('cleaned_winedf.csv')

# %%
finalwinedf.drop_duplicates()
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# 1                                     Avidagos      87   15.0
# 2                                          NaN      87   14.0
# 3                         Reserve Late Harvest      87   13.0
# 4           Vintner's Reserve Wild Child Block      87   65.0
# ...                                        ...     ...    ...
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0
# 129967                                    None      90   75.0
# 129968                                   Kritt      90   30.0
# 129969                                    None      90   32.0
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0
#
#                  province             region_1           region_2  \
# 0       Sicily & Sardinia                 Etna                NaN
# 1                   Douro                  NaN                NaN
# 2                  Oregon    Willamette Valley  Willamette Valley
# 3                Michigan  Lake Michigan Shore                NaN
# 4                  Oregon    Willamette Valley  Willamette Valley
# ...                   ...                  ...                ...
# 129966              Mosel                 None               None
# 129967             Oregon               Oregon       Oregon Other
# 129968             Alsace               Alsace               None
# 129969             Alsace               Alsace               None
# 129970             Alsace               Alsace               None
#
#                taster_name taster_twitter_handle  \
# 0            Kerin O’Keefe          @kerinokeefe
# 1               Roger Voss            @vossroger
# 2             Paul Gregutt           @paulgwine
# 3       Alexander Peartree                   NaN
# 4             Paul Gregutt           @paulgwine
# ...                    ...                   ...
# 129966                 NaN                   NaN
# 129967                 NaN                   NaN
# 129968                 NaN                   NaN
# 129969                 NaN                   NaN
# 129970                 NaN                   NaN
#
#                                                     title         variety  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
# ...                                                   ...             ...
# 129966                                                NaN        Riesling
# 129967                                                NaN      Pinot Noir
# 129968                                                NaN  Gewürztraminer
# 129969                                                NaN      Pinot Gris
# 129970                                                NaN  Gewürztraminer
#
#                                           winery
# 0                                        Nicosia
# 1                            Quinta dos Avidagos
# 2                                      Rainstorm
# 3                                     St. Julian
# 4                                   Sweet Cheeks
# ...                                          ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967                                  Citation
# 129968                           Domaine Gresser
# 129969                      Domaine Marcel Deiss
# 129970                          Domaine Schoffit
#
# [290519 rows x 13 columns]

# %%
print("How many wines are rated?")
print(finalwinedf['points'].count())
print("How many wines are priced")
print(finalwinedf['price'].count())
# Out:
# How many wines are rated?
# 410872
# How many wines are priced
# 379185

# %%
ml = finalwinedf[finalwinedf['price'].notna()]
ml = ml.assign(id=(ml['country']).astype('category').cat.codes)
ml = ml.loc[:, ['id', 'country', 'description', 'designation', 'points', 'price' ,'province', 'region_1', 'region_2', 'taster_name', 'variety', 'title', 'winery']]
ml.price = ml.price.astype(int)
ml
# Out:
#         id   country                                        description  \
# 1       34  Portugal  This is ripe and fruity, a wine that is smooth...
# 2       44        US  Tart and snappy, the flavors of lime flesh and...
# 3       44        US  Pineapple rind, lemon pith and orange blossom ...
# 4       44        US  Much like the regular bottling from 2012, this...
# 5       41     Spain  Blackberry and raspberry aromas show a typical...
# ...     ..       ...                                                ...
# 129966  17   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  44        US  Citation is given as much as a decade of bottl...
# 129968  15    France  Well-drained gravel soil gives this wine its c...
# 129969  15    France  A dry style of Pinot Gris, this is crisp with ...
# 129970  15    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price        province  \
# 1                                     Avidagos      87     15           Douro
# 2                                          NaN      87     14          Oregon
# 3                         Reserve Late Harvest      87     13        Michigan
# 4           Vintner's Reserve Wild Child Block      87     65          Oregon
# 5                                 Ars In Vitro      87     15  Northern Spain
# ...                                        ...     ...    ...             ...
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90     28           Mosel
# 129967                                    None      90     75          Oregon
# 129968                                   Kritt      90     30          Alsace
# 129969                                    None      90     32          Alsace
# 129970           Lieu-dit Harth Cuvée Caroline      90     21          Alsace
#
#                    region_1           region_2         taster_name  \
# 1                       NaN                NaN          Roger Voss
# 2         Willamette Valley  Willamette Valley        Paul Gregutt
# 3       Lake Michigan Shore                NaN  Alexander Peartree
# 4         Willamette Valley  Willamette Valley        Paul Gregutt
# 5                   Navarra                NaN   Michael Schachner
# ...                     ...                ...                 ...
# 129966                 None               None                 NaN
# 129967               Oregon       Oregon Other                 NaN
# 129968               Alsace               None                 NaN
# 129969               Alsace               None                 NaN
# 129970               Alsace               None                 NaN
#
#                    variety                                              title  \
# 1           Portuguese Red      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2               Pinot Gris      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                 Riesling  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4               Pinot Noir  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 5       Tempranillo-Merlot  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...
# ...                    ...                                                ...
# 129966            Riesling                                                NaN
# 129967          Pinot Noir                                                NaN
# 129968      Gewürztraminer                                                NaN
# 129969          Pinot Gris                                                NaN
# 129970      Gewürztraminer                                                NaN
#
#                                           winery
# 1                            Quinta dos Avidagos
# 2                                      Rainstorm
# 3                                     St. Julian
# 4                                   Sweet Cheeks
# 5                                         Tandem
# ...                                          ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967                                  Citation
# 129968                           Domaine Gresser
# 129969                      Domaine Marcel Deiss
# 129970                          Domaine Schoffit
#
# [379185 rows x 13 columns]

# %%
# ml = finalwinedf[finalwinedf['price'].notna()]
print("How many countries are there?")
print(ml["country"].nunique())
print("How many provinces are there?")
print(ml['province'].nunique())
print("How many regions are there?")
print(ml['region_1'].nunique())
print("How many wineries are there?")
print(ml["winery"].nunique())
print("How many id's are there?")
print(ml['id'].nunique())
print("How many varieties are there?")
print(ml['variety'].nunique())
print("How many wines are rated?")
print(ml['points'].describe())
print("How many wines are priced")
print(ml['price'].describe())

# ml
# Out:
# How many countries are there?
# 49
# How many provinces are there?
# 484
# How many regions are there?
# 1308
# How many wineries are there?
# 18158
# How many id's are there?
# 49
# How many varieties are there?
# 746
# How many wines are rated?
# count    379185.000000
# mean         88.192436
# std           3.124675
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          90.000000
# max         100.000000
# Name: points, dtype: float64
# How many wines are priced
# count    379185.000000
# mean         34.555615
# std          39.400606
# min           4.000000
# 25%          16.000000
# 50%          25.000000
# 75%          40.000000
# max        3300.000000
# Name: price, dtype: float64

# %%
#country vs price
plt.scatter(ml['id'], ml['price'])
plt.show()

# %%
#points vs price
plt.scatter(ml['points'], ml['price'])
plt.show()

# %%
#country vs price
temp = ml[ml['variety'].notna()]
plt.scatter(temp['variety'], temp['price'])
plt.show()

# %% [markdown]
# # Hypothesis
# Problem: Predict the price of wine based on features of the wine; country, province, variety, & points

# %% [markdown]
# # Run Linear Regression to Prep for ML

# %%
 # %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.datasets import make_regression

X = ml[["id", "points"]]
y = ml["price"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (379185, 2) (379185, 1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.18951769542306107
# Testing Score: 0.1729305339784295

# %%
#graph some shit
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.title("Residual Plot")
