# %%
# Dependencies
import requests
import json

# Google developer API key
from config import gkey

# Target city
target_city = "Black Star Farms"

# Build the endpoint URL
target_url = ('https://maps.googleapis.com/maps/api/geocode/json?address={0}&key={1}').format(target_city, gkey)

# %%
# Run a request to endpoint and convert result to json
geo_data = requests.get(target_url).json()

# Print the json
print(geo_data)
# Out:
# {'results': [{'access_points': [], 'address_components': [{'long_name': '10844', 'short_name': '10844', 'types': ['street_number']}, {'long_name': 'East Revold Road', 'short_name': 'E Revold Rd', 'types': ['route']}, {'long_name': 'Suttons Bay', 'short_name': 'Suttons Bay', 'types': ['locality', 'political']}, {'long_name': 'Bingham Township', 'short_name': 'Bingham Township', 'types': ['administrative_area_level_3', 'political']}, {'long_name': 'Leelanau County', 'short_name': 'Leelanau County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Michigan', 'short_name': 'MI', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '49682', 'short_name': '49682', 'types': ['postal_code']}], 'formatted_address': '10844 E Revold Rd, Suttons Bay, MI 49682, USA', 'geometry': {'location': {'lat': 44.9337885, 'lng': -85.6361776}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 44.93513748029149, 'lng': -85.6348286197085}, 'southwest': {'lat': 44.9324395197085, 'lng': -85.6375265802915}}}, 'place_id': 'ChIJS_2fe-cqS00ReAbMJtxYYWc', 'plus_code': {'compound_code': 'W9M7+GG Suttons Bay, Suttons Bay Township, MI, United States', 'global_code': '86PPW9M7+GG'}, 'types': ['establishment', 'food', 'lodging', 'point_of_interest', 'restaurant']}, {'access_points': [], 'address_components': [{'long_name': '360', 'short_name': '360', 'types': ['street_number']}, {'long_name': 'McKinley Road East', 'short_name': 'McKinley Rd E', 'types': ['route']}, {'long_name': 'Traverse City', 'short_name': 'Traverse City', 'types': ['locality', 'political']}, {'long_name': 'Peninsula Township', 'short_name': 'Peninsula Township', 'types': ['administrative_area_level_3', 'political']}, {'long_name': 'Grand Traverse County', 'short_name': 'Grand Traverse County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Michigan', 'short_name': 'MI', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '49686', 'short_name': '49686', 'types': ['postal_code']}], 'formatted_address': '360 McKinley Rd E, Traverse City, MI 49686, USA', 'geometry': {'location': {'lat': 44.7963983, 'lng': -85.5683427}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 44.7977472802915, 'lng': -85.56699371970849}, 'southwest': {'lat': 44.7950493197085, 'lng': -85.56969168029151}}}, 'place_id': 'ChIJceRNpPvSH4gRKhzETD_tQt0', 'plus_code': {'compound_code': 'QCWJ+HM Traverse City, Peninsula Township, MI, United States', 'global_code': '86PPQCWJ+HM'}, 'types': ['establishment', 'food', 'point_of_interest', 'tourist_attraction']}], 'status': 'OK'}

# %%
# Print the json (pretty printed)
print(json.dumps(geo_data, indent=4, sort_keys=True))
# Out:
# {
#     "results": [
#         {
#             "access_points": [],
#             "address_components": [
#                 {
#                     "long_name": "10844",
#                     "short_name": "10844",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "East Revold Road",
#                     "short_name": "E Revold Rd",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Suttons Bay",
#                     "short_name": "Suttons Bay",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Bingham Township",
#                     "short_name": "Bingham Township",
#                     "types": [
#                         "administrative_area_level_3",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Leelanau County",
#                     "short_name": "Leelanau County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Michigan",
#                     "short_name": "MI",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "49682",
#                     "short_name": "49682",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "10844 E Revold Rd, Suttons Bay, MI 49682, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 44.9337885,
#                     "lng": -85.6361776
#                 },
#                 "location_type": "ROOFTOP",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 44.93513748029149,
#                         "lng": -85.6348286197085
#                     },
#                     "southwest": {
#                         "lat": 44.9324395197085,
#                         "lng": -85.6375265802915
#                     }
#                 }
#             },
#             "place_id": "ChIJS_2fe-cqS00ReAbMJtxYYWc",
#             "plus_code": {
#                 "compound_code": "W9M7+GG Suttons Bay, Suttons Bay Township, MI, United States",
#                 "global_code": "86PPW9M7+GG"
#             },
#             "types": [
#                 "establishment",
#                 "food",
#                 "lodging",
#                 "point_of_interest",
#                 "restaurant"
#             ]
#         },
#         {
#             "access_points": [],
#             "address_components": [
#                 {
#                     "long_name": "360",
#                     "short_name": "360",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "McKinley Road East",
#                     "short_name": "McKinley Rd E",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Traverse City",
#                     "short_name": "Traverse City",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Peninsula Township",
#                     "short_name": "Peninsula Township",
#                     "types": [
#                         "administrative_area_level_3",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Grand Traverse County",
#                     "short_name": "Grand Traverse County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Michigan",
#                     "short_name": "MI",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "49686",
#                     "short_name": "49686",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "360 McKinley Rd E, Traverse City, MI 49686, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 44.7963983,
#                     "lng": -85.5683427
#                 },
#                 "location_type": "ROOFTOP",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 44.7977472802915,
#                         "lng": -85.56699371970849
#                     },
#                     "southwest": {
#                         "lat": 44.7950493197085,
#                         "lng": -85.56969168029151
#                     }
#                 }
#             },
#             "place_id": "ChIJceRNpPvSH4gRKhzETD_tQt0",
#             "plus_code": {
#                 "compound_code": "QCWJ+HM Traverse City, Peninsula Township, MI, United States",
#                 "global_code": "86PPQCWJ+HM"
#             },
#             "types": [
#                 "establishment",
#                 "food",
#                 "point_of_interest",
#                 "tourist_attraction"
#             ]
#         }
#     ],
#     "status": "OK"
# }

# %%
# Extract latitude and longitude
lat = geo_data["results"][0]["geometry"]["location"]["lat"]
lng = geo_data["results"][0]["geometry"]["location"]["lng"]

# Print the latitude and longitude
print('''
    City: {0}
    Latitude: {1}
    Longitude: {2}
    '''.format(target_city, lat, lng))
# Out:
#     City: Boise, Idaho
#     Latitude: 43.6150186
#     Longitude: -116.2023137
